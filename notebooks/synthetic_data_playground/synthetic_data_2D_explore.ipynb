# %%
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
import numpy as np

# %%
# #############################################################################
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Sythetic data
#
# ## ToDos
#
# 1. make it easy to have beginning and end points be different
# 2. make it automatic to find stays and add individual noise to them
#     1. find stays $\to$ could be used for later labeling and training
#         * **important** this can help validate the algo.
#     2. add individual noise to stays to make them location- and stay-specific
#     3. make same noise for stays at same $x$?

# %%
import importlib
from movement_classify import synthetic_data

# %%
importlib.reload(synthetic_data);
from movement_classify.synthetic_data import get_1bump, get_bumps, get_noisy_bumps

# %% [markdown]
# ## 2D Synthetic data: 2-times the fun

# %%
xxx = np.arange(0,100,0.1)

# %%
dc = {
        "bump1_amp":  0.15, "bump1_slope": 0.5, "bump1_start": -20 , "bump1_end": 80,
        "bump2_amp": -0.5, "bump2_slope": 0.95, "bump2_start": 40 , "bump2_end": 50
     }

dc_noise = {"bump1_eta": 0.035, "bump2_eta": 0.025}

yyy = get_bumps(xxx, **dc)
dc.update(dc_noise)
yyyn = get_noisy_bumps(xxx, **dc)

dc = {
        "bump1_amp":  1.5, "bump1_slope": 0.5, "bump1_start": -20 , "bump1_end": 80,
        "bump2_amp":  -0.5, "bump2_slope": 0.95, "bump2_start": 40 , "bump2_end": 50
     }

dc_noise = {"bump1_eta": 0.025, "bump2_eta": 0.055}

zzz = get_bumps(xxx, **dc)
dc.update(dc_noise)
zzzn = get_noisy_bumps(xxx, **dc)

plt.figure(figsize=(20,10))
#plt.plot(xxx, yyy, '--')
plt.plot(zzzn, yyyn, '.--')

# %%
#ax.scatter(xxx, yyyn, zzzn, marker=m)

from mpl_toolkits.mplot3d import Axes3D

def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize=[20,20])
ax = fig.add_subplot(111, projection='3d')

n = 100
'''
# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)
'''
ax.scatter(zzzn, yyyn, xxx, marker='o', linestyle='-')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('\"time\"')

plt.show();

# %%
dc = {
        "bump1_amp":  0.05, "bump1_slope": 0.5, "bump1_start": -20 , "bump1_end": 80,
        "bump2_amp": -0.5, "bump2_slope": 0.95, "bump2_start": 40 , "bump2_end": 50
     }

dc_noise = {"bump1_eta": 0.035, "bump2_eta": 0.025}

yyy = get_bumps(xxx, **dc)
dc.update(dc_noise)
yyyn = get_noisy_bumps(xxx, **dc)

dc = {
        "bump1_amp":  0.75, "bump1_slope": 0.5, "bump1_start": -20 , "bump1_end": 80,
        "bump2_amp":  -0.5, "bump2_slope": 0.95, "bump2_start": 40 , "bump2_end": 50
     }

dc_noise = {"bump1_eta": 0.025, "bump2_eta": 0.055}

zzz = get_bumps(xxx, **dc)
dc.update(dc_noise)
zzzn = get_noisy_bumps(xxx, **dc)

plt.figure(figsize=(20,10))
#plt.plot(xxx, yyy, '--')
plt.plot(zzzn, yyyn, '.--')

# %%
importlib.reload(synthetic_data);
from movement_classify.synthetic_data import get_frac_mask, get_mask_indices, get_mask

# %%
#get_mask_indices(test_mask)
new_mask = get_mask(xxx.size,0.25)

# %%
# Enabling the `widget` backend.
# This requires jupyter-matplotlib a.k.a. ipympl.
# ipympl can be install via pip or conda.
# %matplotlib widget
# aka import ipympl`

# %%
dc = {
        "bump1_amp":  0.0025, "bump1_slope": 0.5, "bump1_start": -20 , "bump1_end": 80,
        "bump2_amp": -0.25, "bump2_slope": 0.95, "bump2_start": 40 , "bump2_end": 50
     }

dc_noise = {"bump1_eta": 0.085, "bump2_eta": 0.025}

yyy = get_bumps(xxx, **dc)
dc.update(dc_noise)
yyyn = get_noisy_bumps(xxx, **dc)

dc = {
        "bump1_amp":  0.75, "bump1_slope": 0.5, "bump1_start": -20 , "bump1_end": 80,
        "bump2_amp":  -0.25, "bump2_slope": 0.95, "bump2_start": 40 , "bump2_end": 50
     }

dc_noise = {"bump1_eta": 0.055, "bump2_eta": 0.055}

zzz = get_bumps(xxx, **dc)
dc.update(dc_noise)
zzzn = get_noisy_bumps(xxx, **dc)

plt.figure(figsize=(20,10))
#plt.plot(xxx, yyy, '--')
plt.plot(zzzn[new_mask], yyyn[new_mask], '.--')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure(figsize=[20,20])
ax = fig.add_subplot(111, projection='3d')

ax.scatter(zzzn[new_mask], yyyn[new_mask], xxx[new_mask], marker='o', linestyle='-')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dc = {
        "bump1_amp": 0.0025, "bump1_slope": 0.5, "bump1_start": -10, "bump1_end": 0.0,
        "bump2_amp": 1.0000, "bump2_slope": 0.5, "bump2_start":  45, "bump2_end": 60.,
        "bump3_amp": 2.0000, "bump3_slope": 0.5, "bump3_start":  60, "bump3_end": 160.
     }

dc_noise = {"bump1_eta": 0.085, "bump2_eta": 0.025, "bump3_eta": 0.025}

yyy = get_bumps(xxx, **dc)
dc.update(dc_noise)
yyyn = get_noisy_bumps(xxx, **dc)

dc = {
        "bump1_amp":  0.75, "bump1_slope": 0.25, "bump1_start": -10, "bump1_end": 53
     }

dc_noise = {"bump1_eta": 0.055}

zzz = get_bumps(xxx, **dc)
dc.update(dc_noise)
zzzn = get_noisy_bumps(xxx, **dc)

fig, ax = plt.subplots(2,1,figsize=(20,20))

ax[0].plot(xxx,yyyn)
ax[0].plot(xxx,zzzn)
ax[0].grid()

ax[1].plot(zzzn, yyyn, '.--')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(2,1,figsize=(20,20))

ax[0].plot(xxx[new_mask],yyyn[new_mask])
ax[0].plot(xxx[new_mask],zzzn[new_mask])
ax[0].grid()

ax[1].plot(zzzn[new_mask], yyyn[new_mask], '.--')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure(figsize=[20,20])
ax = fig.add_subplot(111, projection='3d')

ax.scatter(zzzn[new_mask], yyyn[new_mask], xxx[new_mask], marker='o', linestyle='-')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('\"time\"')

plt.show();
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
