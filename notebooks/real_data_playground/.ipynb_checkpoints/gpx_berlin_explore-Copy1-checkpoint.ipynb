# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import gpxpy
import gpxpy.gpx

# %%
import pandas as pd
import numpy as np
import datetime

# %%
# !ls -w 1 ../gps_data/*.gpx
# Out:
# ../gps_data/3346484.gpx
# ../gps_data/3346631.gpx
# ../gps_data/3346640.gpx
# ../gps_data/3346793.gpx

# %%
gpxs = [
    '../gps_data/3346484.gpx',
    '../gps_data/3346631.gpx',
    '../gps_data/3346640.gpx',
    '../gps_data/3346793.gpx'
    ]

# %%
# Parsing an existing file:
# -------------------------

#gpx_file = open(gpxs[1], 'r')


gpx_file = open('../gps_data/3348349.gpx', 'r')

# %%
gpx = gpxpy.parse(gpx_file)

# %%
def test_point(point):
    return (point.time != None) &\
           (point.latitude != None) &\
           (point.longitude != None)

# %%
def get_df_from_gpx(gpx):
    
    df = pd.DataFrame(columns=['time','lat','lon'])
    times=[]
    stamps=[]
    lats=[]
    lons=[]
    for track in gpx.tracks:
        for segment in track.segments:
            for point in segment.points:
                if test_point(point):
                    times.append(point.time)
                    stamps.append(point.time.timestamp())
                    lats.append(point.latitude)
                    lons.append(point.longitude)
                else: pass
    df = pd.DataFrame(data={'time':times,'timestamp':stamps,'lat':lats,'lon':lons})

    df.sort_values('timestamp', inplace=True)

    df['timestamp'] = df['timestamp'].astype('int')

    df['dtime'] = df.timestamp.values - df.timestamp.min()

    return df

# %%
df.head()
# Out:
#                        time   timestamp        lat       lon  dtime
# 0 2020-07-01 16:45:51+00:00  1593621951  47.698291  9.280713      0
# 1 2020-07-01 16:45:52+00:00  1593621952  47.698293  9.280736      1
# 2 2020-07-01 16:45:54+00:00  1593621954  47.698279  9.280718      3
# 3 2020-07-01 16:45:55+00:00  1593621955  47.698271  9.280707      4
# 4 2020-07-01 16:45:57+00:00  1593621957  47.698260  9.280687      6

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#gpx = gpxpy.parse(open(gpxs[3], 'r'))
df = get_df_from_gpx(gpx)
plt.plot(df.dtime.values, df.lat.values/df.lat.max(), '.-', lw=1)
plt.plot(df.dtime.values, df.lon.values/df.lon.max(), '.-', lw=1)

# %%
import matplotlib.dates as mdates

# %%
datetime.datetime.strftime(df.time.loc[0], format='%H:%M:%S')
# Out:
# '12:29:38'

# %%
df['time_fmt'] = df.time.apply(lambda x: datetime.datetime.strftime(x, format='%H:%M:%S'))

# %%
df.head()
# Out:
#                        time   timestamp        lat       lon  dtime  time_fmt
# 0 2020-07-04 12:29:38+00:00  1593865778  44.936632  6.257424      0  12:29:38
# 1 2020-07-04 12:29:39+00:00  1593865779  44.936634  6.257418      1  12:29:39
# 2 2020-07-04 12:29:41+00:00  1593865781  44.936650  6.257407      3  12:29:41
# 3 2020-07-04 12:29:44+00:00  1593865784  44.936677  6.257376      6  12:29:44
# 4 2020-07-04 12:29:48+00:00  1593865788  44.936716  6.257342     10  12:29:48

# %%
locator = mdates.AutoDateLocator(minticks=3, maxticks=7)

fig, ax = plt.subplots(2,1, figsize=[20,10])

ax = ax.flatten()

ax[0].plot(df.time.values, df.lat.values, '.-', lw=1)
ax[0].xaxis.set_major_locator(locator)
ax[0].xaxis.set_minor_locator(locator)
ax[0].set_xticklabels([],visible=False)
ax[0].grid();
ax[0].set_ylabel("latitude")


# rotate and align the tick labels so they look better
#fig.autofmt_xdate()

# use a more precise date string for the x axis locations in the
# toolbar
#ax[1].fmt_xdata = mdates.DateFormatter('%H:%M:%S')
#ax[1].set_title('fig.autofmt_xdate fixes the labels')

ax[1].plot(df.time.values, df.lon.values, '.-', lw=1)
ax[1].xaxis.set_major_locator(locator)
ax[1].xaxis.set_minor_locator(locator)
ax[1].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
ax[1].set_ylabel("longitude")
ax[1].grid();

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [join('../gps_data/', f) for f in listdir('../gps_data/') if isfile(join('../gps_data/', f))]

# %%
len(onlyfiles)
# Out:
# 13

# %%
gpx = gpxpy.parse(open(onlyfiles[4], 'r'))
df = get_df_from_gpx(gpx)

# %%
berlin_lat = lambda x: 50 <= x <= 60

# %%
berlin_lat(45)
# Out:
# False

# %%
def check_berlin(df):
    berlin_lat = lambda x: 40 <= x <= 60
    berlin_lon = lambda x: 12 <= x <= 14
    
    return (berlin_lon(df.lon.min()) | \
            berlin_lon(df.lon.max())) & \
           (berlin_lat(df.lat.min()) | \
            berlin_lat(df.lat.max()))

# %%
locator = mdates.AutoDateLocator(minticks=3, maxticks=7)

fig, axs = plt.subplots(6,1, figsize=[50,80])

axs = axs.flatten()

m = 0
for n, gpxfile in enumerate(onlyfiles):

    ax =axs[m]
    
    gpx = gpxpy.parse(open(gpxfile, 'r'))
    df = get_df_from_gpx(gpx)
    
    
    if check_berlin(df) == False: 
        print(n,gpxfile)
        continue
    else:
        print("okay",gpxfile)
       
    ax.plot(df.time.values, df.lat.values, '.-', lw=1)
    
    ax.xaxis.set_major_locator(locator)
    ax.xaxis.set_minor_locator(locator)

    ax.grid();
    ax.set_ylabel("latitude")

    axt = ax.twinx()

    axt.plot(df.time.values, df.lon.values, '.-', color='C1', lw=1)
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    axt.set_ylabel("longitude")
    ax.set_title(gpxfile, fontsize=20)
    m+=1
# Out:
# okay ../gps_data/2642324.gpx
# 1 ../gps_data/3347779.gpx
# okay ../gps_data/2170659.gpx
# 3 ../gps_data/3348349.gpx
# 4 ../gps_data/3346484.gpx
# 5 ../gps_data/123253.gpx
# okay ../gps_data/2778706.gpx
# 7 ../gps_data/3346631.gpx
# 8 ../gps_data/3346640.gpx
# okay ../gps_data/3160264.gpx
# okay ../gps_data/2778884.gpx
# 11 ../gps_data/3346793.gpx
# okay ../gps_data/2641440.gpx

# %%
2442075
# Out:
# 2442075

# %%
onlyfiles[-2]
# Out:
# '../gps_data/3346793.gpx'

# %%
#gpxfile = onlyfiles[10] #0 #10 # 6
gpxfile = '../gps_data/2778884.gpx'
gpx = gpxpy.parse(open(gpxfile, 'r'))
df = get_df_from_gpx(gpx)


if check_berlin(df) == False: 
    print(n,gpxfile)

# %%
locator = mdates.AutoDateLocator(minticks=3, maxticks=7)

fig, ax = plt.subplots(2,1, figsize=[20,10])

ax = ax.flatten()

ax[0].plot(df.time.values, df.lat.values, '.-', lw=1)
ax[0].xaxis.set_major_locator(locator)
ax[0].xaxis.set_minor_locator(locator)
ax[0].set_xticklabels([],visible=False)
ax[0].grid();
ax[0].set_ylabel("latitude")


# rotate and align the tick labels so they look better
#fig.autofmt_xdate()

# use a more precise date string for the x axis locations in the
# toolbar
#ax[1].fmt_xdata = mdates.DateFormatter('%H:%M:%S')
#ax[1].set_title('fig.autofmt_xdate fixes the labels')

ax[1].plot(df.time.values, df.lon.values, '.-', lw=1)
ax[1].xaxis.set_major_locator(locator)
ax[1].xaxis.set_minor_locator(locator)
ax[1].xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
ax[1].set_ylabel("longitude")
ax[1].grid();

# %%
import folium

colors = ['green','darkgreen','lightgreen','darkblue','lightblue',
          'red','blue','gray','darkred','orange','beige',
          'purple','pink','cadetblue','lightgray','black'] 
# 'lightred','darkpurple'

# %%
home_coords = [0.5*(df.lat.max()+df.lat.min()), 0.5*(df.lon.max()+df.lon.min())]

# %%
m = folium.Map(location=home_coords,
                   zoom_start=14, tiles='CartoDBpositron', control_scale=True)


len_colors=len(colors)
ind = 0
lons = df.lon.values
lats = df.lat.values
coords = list(zip(lats,lons))
print(len(coords))
#print coords[:1]
for n in range(50):
    nn = n*200
    nnn = (n+1)*200
    coco = coords[nn:nnn]
    folium.PolyLine(coco, color=colors[n%len_colors]).add_to(m)
#break
    
m
# Out:
# 2027
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
locator = mdates.AutoDateLocator(minticks=3, maxticks=7)

fig, ax = plt.subplots(1,1, figsize=[20,10])

for n in range(50):
    nn = n*200
    nnn = (n+1)*200
    coco = coords[nn:nnn]

    ax.plot(df.time.values[nn:nnn], df.lat.values[nn:nnn], '.-', color=colors[n%len_colors], lw=1)

ax.xaxis.set_major_locator(locator)
ax.xaxis.set_minor_locator(locator)
#ax.set_xticklabels([],visible=False)
ax.grid();
ax.set_ylabel("latitude")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))

# %%
import pyproj as proj

# setup your projections
crs_wgs = proj.Proj(init='epsg:4326') # assuming you're using WGS84 geographic
crs_bng = proj.Proj(init='epsg:27700') # use a locally appropriate projected CRS

# then cast your geographic coordinate pair to the projected system
projx, projy = proj.transform(crs_wgs, crs_bng, df["lon"].values, df["lat"].values)

# %%
locator = mdates.AutoDateLocator(minticks=3, maxticks=7)
from matplotlib import ticker
fig, ax = plt.subplots(1,1, figsize=[20,10])

for n in range(50):
    nn = n*200
    nnn = (n+1)*200
    coco = coords[nn:nnn]

    ax.plot(df.time.values[nn:nnn], projy[nn:nnn]-projy[0], '.-', color=colors[n%len_colors], lw=1)
ax.xaxis.set_major_locator(locator)
ax.xaxis.set_minor_locator(locator)


ax.yaxis.set_major_locator(ticker.MultipleLocator(1000))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(200))

#ax.set_xticklabels([],visible=False)
ax.grid();
ax.set_ylabel("latitude")
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))

# %%
gpx_file = open('../gps_data/3348349.gpx', 'r')
gpx = gpxpy.parse(gpx_file)
#gpx = gpxpy.parse(open(gpxs[3], 'r'))
df = get_df_from_gpx(gpx)
plt.plot(df.dtime.values, df.lat.values/df.lat.max(), '.-', lw=1)
plt.plot(df.dtime.values, df.lon.values/df.lon.max(), '.-', lw=1)

# %%
df.lat.min(),df.lat.max(),df.lon.min(),df.lon.max()
# Out:
# (44.900171, 44.937037, 6.255299, 6.26134)

# %%
fig, axs = plt.subplots(3, 1, constrained_layout=True, figsize=(6, 6))
for nn, ax in enumerate(axs):
    locator = mdates.AutoDateLocator(minticks=3, maxticks=7)
    #formatter = mdates.ConciseDateFormatter(locator)
    ax.xaxis.set_major_locator(locator)
    ax.xaxis.set_major_formatter("%h:%M:%S")

    ax.plot(dates, y)
    ax.set_xlim(lims[nn])
axs[0].set_title('Concise Date Formatter')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-8833db808b79> in <module>
#       4     #formatter = mdates.ConciseDateFormatter(locator)
#       5     ax.xaxis.set_major_locator(locator)
# ----> 6     ax.xaxis.set_major_formatter("%h:%M:%S")
#       7
#       8     ax.plot(dates, y)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in set_major_formatter(self, formatter)
#    1578         """
#    1579         if not isinstance(formatter, mticker.Formatter):
# -> 1580             raise TypeError("formatter argument should be instance of "
#    1581                     "matplotlib.ticker.Formatter")
#    1582         self.isDefault_majfmt = False
#
# TypeError: formatter argument should be instance of matplotlib.ticker.Formatter
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f64517d90d0> (for post_execute):
# ...
